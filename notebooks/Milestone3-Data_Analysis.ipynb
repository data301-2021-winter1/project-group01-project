# %% [markdown]
# # Milestone 3 - Data Analysis

# %% [markdown]
# ## Jarod

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from project_functions1 import load_process_csgo

# %% [markdown]
# ### Plot

# %%
df_csgo_sorted = load_process_csgo('../data/raw/SteamCharts.csv')
df_csgo_sorted
# Out:
#          date        avg      gain  rolling_gain
# 99 2012-11-01    14134.1   3394.62   2348.592857
# 98 2012-12-01   14079.39    -54.71     69.214286
# 97 2013-01-01   16164.22   2084.83      0.750000
# 96 2013-02-01   17372.73   1208.51   1138.694286
# 95 2013-03-01   15959.89  -1412.84    569.391429
# ..        ...        ...       ...           ...
# 7  2020-07-01  625900.81 -45746.65  -8195.227143
# 6  2020-08-01  639957.66  14056.85 -26978.520000
# 5  2020-09-01  606850.32 -33107.34  -7284.500000
# 4  2020-10-01  613666.69   6816.37  10223.171429
# 3  2020-11-01  668754.58  55087.89  16444.632857
#
# [97 rows x 4 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.barplot(x = 'date', y='avg', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='avg'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.scatterplot(x = 'date', y='avg', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='avg'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.barplot(x = 'date', y='gain', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='gain'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.scatterplot(x = 'date', y='gain', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='gain'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.barplot(x = 'date', y='rolling_gain', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='rolling_gain'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 8)
sns.scatterplot(x = 'date', y='rolling_gain', data = df_csgo_sorted)
# Out:
# <AxesSubplot:xlabel='date', ylabel='rolling_gain'>

# %% [markdown]
# ### Research Question
# Does the release of triple A multiplayer fps titles effect the player numbers of CS:GO?

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# From the steam popularity dataset, I extracted the rows about Counter-Strike: Global Offensive, the most popular game on Steam, to process the data and wrangle the average players, gained average players from the previous month, and the seven-month rolling gain average for every month recorded in the dataset. This allows us to have a timeline of the average, the gain, and the seven-month rolling gain average. All we need to do with these timelines is see if there are any dips in the average players that are not a part of a longer pre-existing trend and compare them to the release dates of triple-A titles like Call of Duty, Battlefield, Halo, Overwatch, etc.
#
# The plots above indicate that, while some of the releases of these competing triple-A titles can reduce the player numbers of Counter-Stike: Global Offensive, they do not occur frequently and are not substantial decreases in player numbers. From this, I can conclude that most Counter-Strike Global Offensive players are dedicated to Counter-Strike Global Offensive and are isolated from other video game communities.

# %% [markdown]
# ## Harshal

# %% [markdown]
# ## Lance
